# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn
from datetime import datetime

# %%
data=pd.read_csv("blinkit_customer_feedback.csv")

# %%
df1=pd.DataFrame(data)

# %%
df1.isna().sum()
# Out:
# feedback_id          0
# order_id             0
# customer_id          0
# rating               0
# feedback_text        0
# feedback_category    0
# sentiment            0
# feedback_date        0
# dtype: int64

# %%
df1.columns
# Out:
# Index(['feedback_id', 'order_id', 'customer_id', 'rating', 'feedback_text',
#        'feedback_category', 'sentiment', 'feedback_date'],
#       dtype='object')

# %%
df1[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [feedback_id, order_id, customer_id, rating, feedback_text, feedback_category, sentiment, feedback_date]
# Index: []

# %%
data2=pd.read_csv("blinkit_orders.csv")

# %%
df2=pd.DataFrame(data2)

# %%
df2.count()
# Out:
# order_id                  5000
# customer_id               5000
# order_date                5000
# promised_delivery_time    5000
# actual_delivery_time      5000
# delivery_status           5000
# order_total               5000
# payment_method            5000
# delivery_partner_id       5000
# store_id                  5000
# dtype: int64

# %%
df2.isna().sum()
# Out:
# order_id                  0
# customer_id               0
# order_date                0
# promised_delivery_time    0
# actual_delivery_time      0
# delivery_status           0
# order_total               0
# payment_method            0
# delivery_partner_id       0
# store_id                  0
# dtype: int64

# %%
df2[df2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_date, promised_delivery_time, actual_delivery_time, delivery_status, order_total, payment_method, delivery_partner_id, store_id]
# Index: []

# %%
df1["rating"].mean()
# Out:
# 3.3444

# %%
df1["rating"].median()
# Out:
# 4.0

# %%
sn.distplot(df1["rating"])
# Out:
# C:\Users\rajay\AppData\Local\Temp\ipykernel_7768\3416133946.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df1["rating"])
# <Axes: xlabel='rating', ylabel='Density'>

# %%
a = df1.feedback_id.count()

# %%
df1.groupby("sentiment")["customer_id"].count()
# Out:
# sentiment
# Negative    1642
# Neutral     1738
# Positive    1620
# Name: customer_id, dtype: int64

# %%
merged_df = df1.merge(df2, on='order_id', how='left')

# %%
df3 = merged_df[merged_df["sentiment"]=="Negative"]

# %%
merged_df.groupby("sentiment")["order_total"].mean()
# Out:
# sentiment
# Negative    2210.431425
# Neutral     2208.048337
# Positive    2186.538327
# Name: order_total, dtype: float64

# %%
df3.head()
# Out:
#    feedback_id    order_id  customer_id_x  rating  \
# 1      5450964  1549769649        9573071       3
# 4      3537464  5427684290       83298567       3
# 5      4089724  3265154092       43367112       2
# 7      2259308  6568151549       88866835       2
# 8      7380970  6006693867       24496983       3
#
#                           feedback_text feedback_category sentiment  \
# 1              The order was incorrect.    App Experience  Negative
# 4  Product was damaged during delivery.          Delivery  Negative
# 5  Product was damaged during delivery.  Customer Service  Negative
# 7               I had a bad experience.    App Experience  Negative
# 8  Product was damaged during delivery.          Delivery  Negative
#
#   feedback_date  customer_id_y           order_date promised_delivery_time  \
# 1    2024-05-28        9573071  2024-05-28 13:14:29    2024-05-28 13:25:29
# 4    2023-11-20       83298567  2023-11-20 05:00:39    2023-11-20 05:17:39
# 5    2023-03-18       43367112  2023-03-18 16:29:51    2023-03-18 16:49:51
# 7    2024-03-31       88866835  2024-03-31 06:26:48    2024-03-31 06:37:48
# 8    2023-07-14       24496983  2023-07-13 23:49:36    2023-07-14 00:02:36
#
#   actual_delivery_time delivery_status  order_total payment_method  \
# 1  2024-05-28 13:27:29         On Time       976.55           Cash
# 4  2023-11-20 05:18:39         On Time      2526.68           Cash
# 5  2023-03-18 16:48:51         On Time      3161.43            UPI
# 7  2024-03-31 06:39:48         On Time       905.47           Cash
# 8  2023-07-14 00:05:36         On Time      1371.17           Card
#
#    delivery_partner_id  store_id
# 1                14983      7534
# 4                84315      2741
# 5                  554      3442
# 7                67714       115
# 8                91362      9021

# %%
sn.boxplot(df3["order_total"])
# Out:
# <Axes: ylabel='order_total'>

# %%
sn.boxplot(merged_df["order_total"])
# Out:
# <Axes: ylabel='order_total'>

# %%
sn.boxplot(df2["order_total"])
# Out:
# <Axes: ylabel='order_total'>

# %%
df4= merged_df[merged_df["sentiment"]=="Positive"]

# %%
df4.head()
# Out:
#     feedback_id    order_id  customer_id_x  rating  \
# 6        230696  4898355547       13284996       4
# 13      3158837  5504941865       76512976       5
# 15      8111644  2137046916       12059049       4
# 22      1592958  2268306684       66742602       5
# 32      4382390  8395583761        1989720       4
#
#                           feedback_text feedback_category sentiment  \
# 6                   Highly recommended!   Product Quality  Positive
# 13                  Highly recommended!    App Experience  Positive
# 15  Overall good experience, thank you!  Customer Service  Positive
# 22  Overall good experience, thank you!          Delivery  Positive
# 32      Great prices and fast delivery!    App Experience  Positive
#
#    feedback_date  customer_id_y           order_date promised_delivery_time  \
# 6     2023-04-16       13284996  2023-04-16 18:50:37    2023-04-16 19:01:37
# 13    2024-01-28       76512976  2024-01-28 02:39:11    2024-01-28 02:55:11
# 15    2024-02-03       12059049  2024-02-03 08:50:32    2024-02-03 09:03:32
# 22    2024-05-28       66742602  2024-05-28 14:59:08    2024-05-28 15:11:08
# 32    2024-08-04        1989720  2024-08-04 23:35:44    2024-08-04 23:53:44
#
#    actual_delivery_time   delivery_status  order_total payment_method  \
# 6   2023-04-16 19:02:37           On Time       956.40           Card
# 13  2024-01-28 03:06:11  Slightly Delayed      2287.68         Wallet
# 15  2024-02-03 09:01:32           On Time      3373.96            UPI
# 22  2024-05-28 15:10:08           On Time      2991.57         Wallet
# 32  2024-08-04 23:48:44           On Time       410.62            UPI
#
#     delivery_partner_id  store_id
# 6                 14630      1318
# 13                56077      9809
# 15                12377      1007
# 22                65733      6847
# 32                84816      5448

# %%
merged_df.head()
# Out:
#    feedback_id    order_id  customer_id_x  rating  \
# 0      2234710  1961864118       30065862       4
# 1      5450964  1549769649        9573071       3
# 2       482108  9185164487       45477575       3
# 3      4823104  9644738826       88067569       4
# 4      3537464  5427684290       83298567       3
#
#                           feedback_text feedback_category sentiment  \
# 0         It was okay, nothing special.          Delivery   Neutral
# 1              The order was incorrect.    App Experience  Negative
# 2         It was okay, nothing special.    App Experience   Neutral
# 3      The product met my expectations.    App Experience   Neutral
# 4  Product was damaged during delivery.          Delivery  Negative
#
#   feedback_date  customer_id_y           order_date promised_delivery_time  \
# 0    2024-07-17       30065862  2024-07-17 08:34:01    2024-07-17 08:52:01
# 1    2024-05-28        9573071  2024-05-28 13:14:29    2024-05-28 13:25:29
# 2    2024-09-23       45477575  2024-09-23 13:07:12    2024-09-23 13:25:12
# 3    2023-11-24       88067569  2023-11-24 16:16:56    2023-11-24 16:34:56
# 4    2023-11-20       83298567  2023-11-20 05:00:39    2023-11-20 05:17:39
#
#   actual_delivery_time delivery_status  order_total payment_method  \
# 0  2024-07-17 08:47:01         On Time      3197.07           Cash
# 1  2024-05-28 13:27:29         On Time       976.55           Cash
# 2  2024-09-23 13:29:12         On Time       839.05            UPI
# 3  2023-11-24 16:33:56         On Time       440.23           Card
# 4  2023-11-20 05:18:39         On Time      2526.68           Cash
#
#    delivery_partner_id  store_id
# 0                63230      4771
# 1                14983      7534
# 2                39859      9886
# 3                61497      7917
# 4                84315      2741

# %%
sentiment_mapping = {'Positive': 1, 'Neutral': 0, 'Negative': -1}
merged_df['sentiment_numeric'] = merged_df['sentiment'].map(sentiment_mapping)

# %%
merged_df["sentiment_numeric"].corr(merged_df["order_total"])
# Out:
# -0.00739210400347186

# %%
merged_df
# Out:
#       feedback_id    order_id  customer_id_x  rating  \
# 0         2234710  1961864118       30065862       4
# 1         5450964  1549769649        9573071       3
# 2          482108  9185164487       45477575       3
# 3         4823104  9644738826       88067569       4
# 4         3537464  5427684290       83298567       3
# ...           ...         ...            ...     ...
# 4995      9024060  1669690997       62600289       3
# 4996      4715968  8340761903       53640286       3
# 4997      9621021  5936301790       87059497       4
# 4998      1134095  5710579377       67310893       4
# 4999      6578433  2494813730       28663279       4
#
#                              feedback_text feedback_category sentiment  \
# 0            It was okay, nothing special.          Delivery   Neutral
# 1                 The order was incorrect.    App Experience  Negative
# 2            It was okay, nothing special.    App Experience   Neutral
# 3         The product met my expectations.    App Experience   Neutral
# 4     Product was damaged during delivery.          Delivery  Negative
# ...                                    ...               ...       ...
# 4995            Taste was not as expected.   Product Quality  Negative
# 4996    Average experience, could improve.   Product Quality   Neutral
# 4997    Average experience, could improve.    App Experience   Neutral
# 4998    Average experience, could improve.          Delivery   Neutral
# 4999         It was okay, nothing special.  Customer Service   Neutral
#
#      feedback_date  customer_id_y           order_date promised_delivery_time  \
# 0       2024-07-17       30065862  2024-07-17 08:34:01    2024-07-17 08:52:01
# 1       2024-05-28        9573071  2024-05-28 13:14:29    2024-05-28 13:25:29
# 2       2024-09-23       45477575  2024-09-23 13:07:12    2024-09-23 13:25:12
# 3       2023-11-24       88067569  2023-11-24 16:16:56    2023-11-24 16:34:56
# 4       2023-11-20       83298567  2023-11-20 05:00:39    2023-11-20 05:17:39
# ...            ...            ...                  ...                    ...
# 4995    2023-12-25       62600289  2023-12-25 15:46:20    2023-12-25 16:05:20
# 4996    2023-11-27       53640286  2023-11-27 09:18:43    2023-11-27 09:38:43
# 4997    2024-06-21       87059497  2024-06-21 19:09:09    2024-06-21 19:23:09
# 4998    2024-06-06       67310893  2024-06-06 14:58:13    2024-06-06 15:12:13
# 4999    2023-08-23       28663279  2023-08-23 12:04:18    2023-08-23 12:20:18
#
#      actual_delivery_time delivery_status  order_total payment_method  \
# 0     2024-07-17 08:47:01         On Time      3197.07           Cash
# 1     2024-05-28 13:27:29         On Time       976.55           Cash
# 2     2024-09-23 13:29:12         On Time       839.05            UPI
# 3     2023-11-24 16:33:56         On Time       440.23           Card
# 4     2023-11-20 05:18:39         On Time      2526.68           Cash
# ...                   ...             ...          ...            ...
# 4995  2023-12-25 16:10:20         On Time      1132.33           Cash
# 4996  2023-11-27 09:36:43         On Time      2372.01           Cash
# 4997  2024-06-21 19:26:09         On Time      3158.35           Cash
# 4998  2024-06-06 15:10:13         On Time      1918.92            UPI
# 4999  2023-08-23 12:21:18         On Time      1879.46           Card
#
#       delivery_partner_id  store_id  sentiment_numeric
# 0                   63230      4771                  0
# 1                   14983      7534                 -1
# 2                   39859      9886                  0
# 3                   61497      7917                  0
# 4                   84315      2741                 -1
# ...                   ...       ...                ...
# 4995                90914      1587                 -1
# 4996                27952      3458                  0
# 4997                 9590      7424                  0
# 4998                29940      6128                  0
# 4999                32851      5588                  0
#
# [5000 rows x 18 columns]

# %%
negative_reviews = df1[df1['sentiment'] == 'Negative']

# %%
negative_reviews.head()
# Out:
#    feedback_id    order_id  customer_id  rating  \
# 1      5450964  1549769649      9573071       3
# 4      3537464  5427684290     83298567       3
# 5      4089724  3265154092     43367112       2
# 7      2259308  6568151549     88866835       2
# 8      7380970  6006693867     24496983       3
#
#                           feedback_text feedback_category sentiment  \
# 1              The order was incorrect.    App Experience  Negative
# 4  Product was damaged during delivery.          Delivery  Negative
# 5  Product was damaged during delivery.  Customer Service  Negative
# 7               I had a bad experience.    App Experience  Negative
# 8  Product was damaged during delivery.          Delivery  Negative
#
#   feedback_date
# 1    2024-05-28
# 4    2023-11-20
# 5    2023-03-18
# 7    2024-03-31
# 8    2023-07-14

# %%
negative_reviews['feedback_date'] = pd.to_datetime(negative_reviews['feedback_date'])
# Out:
# C:\Users\rajay\AppData\Local\Temp\ipykernel_7768\3132787204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative_reviews['feedback_date'] = pd.to_datetime(negative_reviews['feedback_date'])

# %%
negative_reviews_sorted = negative_reviews.sort_values(by=['customer_id', 'feedback_date'])

# %%
n_review= negative_reviews_sorted.groupby('customer_id').first().reset_index()

# %%
n_review.count()[0]
# Out:
# C:\Users\rajay\AppData\Local\Temp\ipykernel_7768\1906131229.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   n_review.count()[0]
# 1206

# %%
n_review.head()
# Out:
#    customer_id  feedback_id    order_id  rating  \
# 0        31813      7669412  7997347191       3
# 1       119099      9132205  6538760883       3
# 2       188838      5156321  1282422181       3
# 3       191616       415485  9989636336       3
# 4       211163      7305285  4056304110       3
#
#                           feedback_text feedback_category sentiment  \
# 0  Product was damaged during delivery.    App Experience  Negative
# 1              The order was incorrect.    App Experience  Negative
# 2   Very disappointed with the quality.    App Experience  Negative
# 3  Delivery was late and I was unhappy.   Product Quality  Negative
# 4   Very disappointed with the quality.   Product Quality  Negative
#
#   feedback_date
# 0    2024-07-11
# 1    2024-04-19
# 2    2024-02-19
# 3    2024-05-24
# 4    2023-11-25

# %%
main_df = n_review.merge(df2, on='order_id', how='left')

# %%
main_df.head()
# Out:
#    customer_id_x  feedback_id    order_id  rating  \
# 0          31813      7669412  7997347191       3
# 1         119099      9132205  6538760883       3
# 2         188838      5156321  1282422181       3
# 3         191616       415485  9989636336       3
# 4         211163      7305285  4056304110       3
#
#                           feedback_text feedback_category sentiment  \
# 0  Product was damaged during delivery.    App Experience  Negative
# 1              The order was incorrect.    App Experience  Negative
# 2   Very disappointed with the quality.    App Experience  Negative
# 3  Delivery was late and I was unhappy.   Product Quality  Negative
# 4   Very disappointed with the quality.   Product Quality  Negative
#
#   feedback_date  customer_id_y           order_date promised_delivery_time  \
# 0    2024-07-11          31813  2024-07-11 03:32:42    2024-07-11 03:48:42
# 1    2024-04-19         119099  2024-04-19 13:46:57    2024-04-19 14:06:57
# 2    2024-02-19         188838  2024-02-19 14:40:22    2024-02-19 14:52:22
# 3    2024-05-24         191616  2024-05-24 07:26:24    2024-05-24 07:45:24
# 4    2023-11-25         211163  2023-11-25 12:03:51    2023-11-25 12:19:51
#
#   actual_delivery_time        delivery_status  order_total payment_method  \
# 0  2024-07-11 04:01:42       Slightly Delayed      4498.83         Wallet
# 1  2024-04-19 14:06:57                On Time      5122.10            UPI
# 2  2024-02-19 14:59:22       Slightly Delayed      1116.88            UPI
# 3  2024-05-24 07:59:24       Slightly Delayed      2425.95           Cash
# 4  2023-11-25 12:37:51  Significantly Delayed      3567.36            UPI
#
#    delivery_partner_id  store_id
# 0                11517      1071
# 1                 6246      3096
# 2                 1443      9970
# 3                91946      7821
# 4                32614      3514

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1206 entries, 0 to 1205
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id_x           1206 non-null   int64
#  1   feedback_id             1206 non-null   int64
#  2   order_id                1206 non-null   int64
#  3   rating                  1206 non-null   int64
#  4   feedback_text           1206 non-null   object
#  5   feedback_category       1206 non-null   object
#  6   sentiment               1206 non-null   object
#  7   feedback_date           1206 non-null   datetime64[ns]
#  8   customer_id_y           1206 non-null   int64
#  9   order_date              1206 non-null   object
#  10  promised_delivery_time  1206 non-null   object
#  11  actual_delivery_time    1206 non-null   object
#  12  delivery_status         1206 non-null   object
#  13  order_total             1206 non-null   float64
#  14  payment_method          1206 non-null   object
#  15  delivery_partner_id     1206 non-null   int64
#  16  store_id                1206 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(7), object(8)
# memory usage: 160.3+ KB

# %%
main_df.head()
# Out:
#    customer_id_x  feedback_id    order_id  rating  \
# 0          31813      7669412  7997347191       3
# 1         119099      9132205  6538760883       3
# 2         188838      5156321  1282422181       3
# 3         191616       415485  9989636336       3
# 4         211163      7305285  4056304110       3
#
#                           feedback_text feedback_category sentiment  \
# 0  Product was damaged during delivery.    App Experience  Negative
# 1              The order was incorrect.    App Experience  Negative
# 2   Very disappointed with the quality.    App Experience  Negative
# 3  Delivery was late and I was unhappy.   Product Quality  Negative
# 4   Very disappointed with the quality.   Product Quality  Negative
#
#   feedback_date  customer_id_y           order_date promised_delivery_time  \
# 0    2024-07-11          31813  2024-07-11 03:32:42    2024-07-11 03:48:42
# 1    2024-04-19         119099  2024-04-19 13:46:57    2024-04-19 14:06:57
# 2    2024-02-19         188838  2024-02-19 14:40:22    2024-02-19 14:52:22
# 3    2024-05-24         191616  2024-05-24 07:26:24    2024-05-24 07:45:24
# 4    2023-11-25         211163  2023-11-25 12:03:51    2023-11-25 12:19:51
#
#   actual_delivery_time        delivery_status  order_total payment_method  \
# 0  2024-07-11 04:01:42       Slightly Delayed      4498.83         Wallet
# 1  2024-04-19 14:06:57                On Time      5122.10            UPI
# 2  2024-02-19 14:59:22       Slightly Delayed      1116.88            UPI
# 3  2024-05-24 07:59:24       Slightly Delayed      2425.95           Cash
# 4  2023-11-25 12:37:51  Significantly Delayed      3567.36            UPI
#
#    delivery_partner_id  store_id
# 0                11517      1071
# 1                 6246      3096
# 2                 1443      9970
# 3                91946      7821
# 4                32614      3514

# %%
main_df["order_date"] = pd.to_datetime(main_df["order_date"]).dt.strftime('%Y-%m-%d')

# %%
main_df.head()
# Out:
#    customer_id_x  feedback_id    order_id  rating  \
# 0          31813      7669412  7997347191       3
# 1         119099      9132205  6538760883       3
# 2         188838      5156321  1282422181       3
# 3         191616       415485  9989636336       3
# 4         211163      7305285  4056304110       3
#
#                           feedback_text feedback_category sentiment  \
# 0  Product was damaged during delivery.    App Experience  Negative
# 1              The order was incorrect.    App Experience  Negative
# 2   Very disappointed with the quality.    App Experience  Negative
# 3  Delivery was late and I was unhappy.   Product Quality  Negative
# 4   Very disappointed with the quality.   Product Quality  Negative
#
#   feedback_date  customer_id_y  order_date promised_delivery_time  \
# 0    2024-07-11          31813  2024-07-11    2024-07-11 03:48:42
# 1    2024-04-19         119099  2024-04-19    2024-04-19 14:06:57
# 2    2024-02-19         188838  2024-02-19    2024-02-19 14:52:22
# 3    2024-05-24         191616  2024-05-24    2024-05-24 07:45:24
# 4    2023-11-25         211163  2023-11-25    2023-11-25 12:19:51
#
#   actual_delivery_time        delivery_status  order_total payment_method  \
# 0  2024-07-11 04:01:42       Slightly Delayed      4498.83         Wallet
# 1  2024-04-19 14:06:57                On Time      5122.10            UPI
# 2  2024-02-19 14:59:22       Slightly Delayed      1116.88            UPI
# 3  2024-05-24 07:59:24       Slightly Delayed      2425.95           Cash
# 4  2023-11-25 12:37:51  Significantly Delayed      3567.36            UPI
#
#    delivery_partner_id  store_id
# 0                11517      1071
# 1                 6246      3096
# 2                 1443      9970
# 3                91946      7821
# 4                32614      3514

# %%
main_df["Period"] = np.where(main_df["order_date"] < main_df["feedback_date"], "Backward",
    np.where(main_df["order_date"] > main_df["feedback_date"],"Forward","Same"))

# %%
main_df.head()
# Out:
#    customer_id_x  feedback_id    order_id  rating  \
# 0          31813      7669412  7997347191       3
# 1         119099      9132205  6538760883       3
# 2         188838      5156321  1282422181       3
# 3         191616       415485  9989636336       3
# 4         211163      7305285  4056304110       3
#
#                           feedback_text feedback_category sentiment  \
# 0  Product was damaged during delivery.    App Experience  Negative
# 1              The order was incorrect.    App Experience  Negative
# 2   Very disappointed with the quality.    App Experience  Negative
# 3  Delivery was late and I was unhappy.   Product Quality  Negative
# 4   Very disappointed with the quality.   Product Quality  Negative
#
#   feedback_date  customer_id_y  order_date promised_delivery_time  \
# 0    2024-07-11          31813  2024-07-11    2024-07-11 03:48:42
# 1    2024-04-19         119099  2024-04-19    2024-04-19 14:06:57
# 2    2024-02-19         188838  2024-02-19    2024-02-19 14:52:22
# 3    2024-05-24         191616  2024-05-24    2024-05-24 07:45:24
# 4    2023-11-25         211163  2023-11-25    2023-11-25 12:19:51
#
#   actual_delivery_time        delivery_status  order_total payment_method  \
# 0  2024-07-11 04:01:42       Slightly Delayed      4498.83         Wallet
# 1  2024-04-19 14:06:57                On Time      5122.10            UPI
# 2  2024-02-19 14:59:22       Slightly Delayed      1116.88            UPI
# 3  2024-05-24 07:59:24       Slightly Delayed      2425.95           Cash
# 4  2023-11-25 12:37:51  Significantly Delayed      3567.36            UPI
#
#    delivery_partner_id  store_id Period
# 0                11517      1071   Same
# 1                 6246      3096   Same
# 2                 1443      9970   Same
# 3                91946      7821   Same
# 4                32614      3514   Same

# %%
main_df.groupby("Period")["Period"].count()
# Out:
# Period
# Backward      15
# Same        1191
# Name: Period, dtype: int64

# %%
main_df.to_csv("Blinkit_master_data.csv")

# %%
master_data = main_df.copy()

# %%
master_data=pd.DataFrame(master_data)

# %%
master_data.head()
# Out:
#    customer_id_x  feedback_id    order_id  rating  \
# 0          31813      7669412  7997347191       3
# 1         119099      9132205  6538760883       3
# 2         188838      5156321  1282422181       3
# 3         191616       415485  9989636336       3
# 4         211163      7305285  4056304110       3
#
#                           feedback_text feedback_category sentiment  \
# 0  Product was damaged during delivery.    App Experience  Negative
# 1              The order was incorrect.    App Experience  Negative
# 2   Very disappointed with the quality.    App Experience  Negative
# 3  Delivery was late and I was unhappy.   Product Quality  Negative
# 4   Very disappointed with the quality.   Product Quality  Negative
#
#   feedback_date  customer_id_y  order_date promised_delivery_time  \
# 0    2024-07-11          31813  2024-07-11    2024-07-11 03:48:42
# 1    2024-04-19         119099  2024-04-19    2024-04-19 14:06:57
# 2    2024-02-19         188838  2024-02-19    2024-02-19 14:52:22
# 3    2024-05-24         191616  2024-05-24    2024-05-24 07:45:24
# 4    2023-11-25         211163  2023-11-25    2023-11-25 12:19:51
#
#   actual_delivery_time        delivery_status  order_total payment_method  \
# 0  2024-07-11 04:01:42       Slightly Delayed      4498.83         Wallet
# 1  2024-04-19 14:06:57                On Time      5122.10            UPI
# 2  2024-02-19 14:59:22       Slightly Delayed      1116.88            UPI
# 3  2024-05-24 07:59:24       Slightly Delayed      2425.95           Cash
# 4  2023-11-25 12:37:51  Significantly Delayed      3567.36            UPI
#
#    delivery_partner_id  store_id Period
# 0                11517      1071   Same
# 1                 6246      3096   Same
# 2                 1443      9970   Same
# 3                91946      7821   Same
# 4                32614      3514   Same

# %%
master_data.groupby("Period")["Period"].count()
# Out:
# Period
# Backward      15
# Same        1191
# Name: Period, dtype: int64

# %%
master_data["order_date"] = pd.to_datetime(master_data["order_date"])
master_data["Days_gap"] = (master_data["order_date"] - master_data["feedback_date"]).dt.days.abs()

# %%
master_data.head()
# Out:
#    customer_id_x  feedback_id    order_id  rating  \
# 0          31813      7669412  7997347191       3
# 1         119099      9132205  6538760883       3
# 2         188838      5156321  1282422181       3
# 3         191616       415485  9989636336       3
# 4         211163      7305285  4056304110       3
#
#                           feedback_text feedback_category sentiment  \
# 0  Product was damaged during delivery.    App Experience  Negative
# 1              The order was incorrect.    App Experience  Negative
# 2   Very disappointed with the quality.    App Experience  Negative
# 3  Delivery was late and I was unhappy.   Product Quality  Negative
# 4   Very disappointed with the quality.   Product Quality  Negative
#
#   feedback_date  customer_id_y order_date promised_delivery_time  \
# 0    2024-07-11          31813 2024-07-11    2024-07-11 03:48:42
# 1    2024-04-19         119099 2024-04-19    2024-04-19 14:06:57
# 2    2024-02-19         188838 2024-02-19    2024-02-19 14:52:22
# 3    2024-05-24         191616 2024-05-24    2024-05-24 07:45:24
# 4    2023-11-25         211163 2023-11-25    2023-11-25 12:19:51
#
#   actual_delivery_time        delivery_status  order_total payment_method  \
# 0  2024-07-11 04:01:42       Slightly Delayed      4498.83         Wallet
# 1  2024-04-19 14:06:57                On Time      5122.10            UPI
# 2  2024-02-19 14:59:22       Slightly Delayed      1116.88            UPI
# 3  2024-05-24 07:59:24       Slightly Delayed      2425.95           Cash
# 4  2023-11-25 12:37:51  Significantly Delayed      3567.36            UPI
#
#    delivery_partner_id  store_id Period  Days_gap
# 0                11517      1071   Same         0
# 1                 6246      3096   Same         0
# 2                 1443      9970   Same         0
# 3                91946      7821   Same         0
# 4                32614      3514   Same         0

# %%
master_data=master_data[master_data["Days_gap"]<=30]

# %%
master_data.head()
# Out:
#    customer_id_x  feedback_id    order_id  rating  \
# 0          31813      7669412  7997347191       3
# 1         119099      9132205  6538760883       3
# 2         188838      5156321  1282422181       3
# 3         191616       415485  9989636336       3
# 4         211163      7305285  4056304110       3
#
#                           feedback_text feedback_category sentiment  \
# 0  Product was damaged during delivery.    App Experience  Negative
# 1              The order was incorrect.    App Experience  Negative
# 2   Very disappointed with the quality.    App Experience  Negative
# 3  Delivery was late and I was unhappy.   Product Quality  Negative
# 4   Very disappointed with the quality.   Product Quality  Negative
#
#   feedback_date  customer_id_y order_date promised_delivery_time  \
# 0    2024-07-11          31813 2024-07-11    2024-07-11 03:48:42
# 1    2024-04-19         119099 2024-04-19    2024-04-19 14:06:57
# 2    2024-02-19         188838 2024-02-19    2024-02-19 14:52:22
# 3    2024-05-24         191616 2024-05-24    2024-05-24 07:45:24
# 4    2023-11-25         211163 2023-11-25    2023-11-25 12:19:51
#
#   actual_delivery_time        delivery_status  order_total payment_method  \
# 0  2024-07-11 04:01:42       Slightly Delayed      4498.83         Wallet
# 1  2024-04-19 14:06:57                On Time      5122.10            UPI
# 2  2024-02-19 14:59:22       Slightly Delayed      1116.88            UPI
# 3  2024-05-24 07:59:24       Slightly Delayed      2425.95           Cash
# 4  2023-11-25 12:37:51  Significantly Delayed      3567.36            UPI
#
#    delivery_partner_id  store_id Period  Days_gap
# 0                11517      1071   Same         0
# 1                 6246      3096   Same         0
# 2                 1443      9970   Same         0
# 3                91946      7821   Same         0
# 4                32614      3514   Same         0

# %%
pivot_master_df=master_data.pivot(index=['customer_id_x','feedback_id','order_id','rating','delivery_status','payment_method','delivery_partner_id',
                                         'store_id'],columns='Period',values='order_total')

# %%
pivot_master_df.to_csv("Pivoted_master_df.csv")

# %%
pivot_master_df=pd.read_csv("Pivoted_master_df.csv")

# %%
pivot_backward = pivot_master_df.groupby("customer_id_x")["Backward"].mean()

# %%
pivot_backward = pd.DataFrame(pivot_backward)

# %%
pivot_backward.head()
# Out:
#                Backward
# customer_id_x
# 31813               NaN
# 119099              NaN
# 188838              NaN
# 191616              NaN
# 211163              NaN

# %%
pivot_forward = pivot_master_df.groupby("customer_id_x")["Same"].mean()

# %%
pivot_forward = pd.DataFrame(pivot_forward)

# %%
pivot_forward.head()
# Out:
#                   Same
# customer_id_x
# 31813          4498.83
# 119099         5122.10
# 188838         1116.88
# 191616         2425.95
# 211163         3567.36

# %%
pivot_forward.count()[0]
# Out:
# C:\Users\rajay\AppData\Local\Temp\ipykernel_7768\1651225281.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pivot_forward.count()[0]
# 1191

# %%
pivot_backward.count()[0]
# Out:
# C:\Users\rajay\AppData\Local\Temp\ipykernel_7768\1209943529.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pivot_backward.count()[0]
# 15

# %%
import os

if not os.path.exists("CustomerID.xlsx"):
	# Create a sample dataframe with customer_id_x column
	sample_df = master_data[["customer_id_x"]].drop_duplicates()
	sample_df.to_excel("CustomerID.xlsx", index=False)

F_customer = pd.read_excel("CustomerID.xlsx")

# %%
F_customer.head()
# Out:
#    customer_id_x
# 0          31813
# 1         119099
# 2         188838
# 3         191616
# 4         211163

# %%
F_customer = F_customer.merge(pivot_forward, on='customer_id_x', how='left')

# %%
F_customer = F_customer.merge(pivot_backward, on='customer_id_x', how='left')

# %%
F_customer.fillna(0,inplace=True)

# %%
F_customer
# Out:
#       customer_id_x     Same  Backward
# 0             31813  4498.83       0.0
# 1            119099  5122.10       0.0
# 2            188838  1116.88       0.0
# 3            191616  2425.95       0.0
# 4            211163  3567.36       0.0
# ...             ...      ...       ...
# 1201       99707100  5027.50       0.0
# 1202       99714944   888.12       0.0
# 1203       99729547   729.04       0.0
# 1204       99734256  4341.21       0.0
# 1205       99784559  2527.14       0.0
#
# [1206 rows x 3 columns]

# %%
F_customer.to_csv("customer_feedback_analysis.csv")

# %%
sn.boxplot(F_customer["Same"])
# Out:
# <Axes: ylabel='Same'>

# %%
sn.boxplot(F_customer["Backward"])
# Out:
# <Axes: ylabel='Backward'>

# %%
F_customer.describe()
# Out:
#        customer_id_x         Same     Backward
# count   1.206000e+03  1206.000000  1206.000000
# mean    5.039070e+07  2178.255498    25.929701
# std     2.922701e+07  1323.020480   255.287121
# min     3.181300e+04     0.000000     0.000000
# 25%     2.466986e+07  1065.817500     0.000000
# 50%     5.099116e+07  2096.090000     0.000000
# 75%     7.615357e+07  3140.932500     0.000000
# max     9.978456e+07  6458.900000  3869.920000

# %%
from scipy.stats import ttest_rel

# %%
test = F_customer[(F_customer['Backward'] != 0) & (F_customer['Same'] != 0)]

# %%
t_stat, p_value = ttest_rel(F_customer['Backward'], F_customer['Same'])

# %%
p_value
# Out:
# 8e-323

# %%
F_customer
# Out:
#       customer_id_x     Same  Backward
# 0             31813  4498.83       0.0
# 1            119099  5122.10       0.0
# 2            188838  1116.88       0.0
# 3            191616  2425.95       0.0
# 4            211163  3567.36       0.0
# ...             ...      ...       ...
# 1201       99707100  5027.50       0.0
# 1202       99714944   888.12       0.0
# 1203       99729547   729.04       0.0
# 1204       99734256  4341.21       0.0
# 1205       99784559  2527.14       0.0
#
# [1206 rows x 3 columns]

# %%
F_customer
# Out:
#       customer_id_x     Same  Backward
# 0             31813  4498.83       0.0
# 1            119099  5122.10       0.0
# 2            188838  1116.88       0.0
# 3            191616  2425.95       0.0
# 4            211163  3567.36       0.0
# ...             ...      ...       ...
# 1201       99707100  5027.50       0.0
# 1202       99714944   888.12       0.0
# 1203       99729547   729.04       0.0
# 1204       99734256  4341.21       0.0
# 1205       99784559  2527.14       0.0
#
# [1206 rows x 3 columns]
